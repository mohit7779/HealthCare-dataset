# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\HP\Downloads\archive (10)\healthcare_dataset.csv")
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df.head(5)
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
df.shape
# Out:
# (55500, 15)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Name                   object
# Age                     int64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount        float64
# Room Number             int64
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# dtype: object

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  55500.000000    55500.000000  55500.000000
# mean      51.539459    25539.316097    301.134829
# std       19.602454    14211.454431    115.243069
# min       13.000000    -2008.492140    101.000000
# 25%       35.000000    13241.224652    202.000000
# 50%       52.000000    25538.069376    302.000000
# 75%       68.000000    37820.508436    401.000000
# max       89.000000    52764.276736    500.000000

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
sns.histplot(df["Age"],bins =30,kde = True , color = "skyblue")
plt.title("Age Distribution of Patients")
plt.xlabel("Age")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
sns.histplot(df["Billing Amount"],bins=30,kde=True,color="salmon")
plt.title("distribution of Billing Amount")
plt.xlabel("Billing Amount")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
sns.boxplot(x="Admission Type",y="Billing Amount",data = df,palette = "Set2")
plt.title("Billing Amount By Admission Type")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6772\821900500.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Admission Type",y="Billing Amount",data = df,palette = "Set2")
# Text(0.5, 1.0, 'Billing Amount By Admission Type')

# %%
sns.countplot(x="Medical Condition",hue="Gender",data = df,palette = "viridis")
plt.title("Medical Condition By Gender")
# Out:
# Text(0.5, 1.0, 'Medical Condition By Gender')

# %%
sns.countplot(x="Admission Type",data=df,palette = "pastel")
plt.title("Distribution of Admission Type")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6772\189557946.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Admission Type",data=df,palette = "pastel")
# Text(0.5, 1.0, 'Distribution of Admission Type')

# %%
sns.boxplot(x="Test Results",y="Billing Amount",data=df,palette = "muted")
plt.title("Distribution of Test Results By Billing Amount")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6772\3322331848.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Test Results",y="Billing Amount",data=df,palette = "muted")
# Text(0.5, 1.0, 'Distribution of Test Results By Billing Amount')

# %%
sns.countplot(x="Gender",data=df,palette = "pastel")
plt.title("Gender Distribution By Patients")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6772\1162486831.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Gender",data=df,palette = "pastel")
# Text(0.5, 1.0, 'Gender Distribution By Patients')

# %%
avg_billing_condition = df.groupby("Medical Condition")["Billing Amount"].mean().sort_values()
sns.barplot(x=avg_billing_condition.index,y=avg_billing_condition.values,palette = "Blues_d")
plt.title("Average Billing by Medical Condition")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6772\2565043897.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_billing_condition.index,y=avg_billing_condition.values,palette = "Blues_d")
# Text(0.5, 1.0, 'Average Billing by Medical Condition')

# %%
df.head(5)
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
condition_admission_count = df.pivot_table(index="Medical Condition",columns="Admission Type",aggfunc="size",fill_value=0)
sns.heatmap(condition_admission_count,annot=True,cmap="YlGnBu",fmt="d")
plt.title("Medical Condition and Admission Type Frequency")
# Out:
# Text(0.5, 1.0, 'Medical Condition and Admission Type Frequency')

# %%
df["Medical Condition"].value_counts().plot.pie(autopct="%2.2f%%")
plt.title("Distribution Of Medical Condition By Percentage")
# Out:
# Text(0.5, 1.0, 'Distribution Of Medical Condition By Percentage')

# %% [markdown]
# #  ANOVA TEST

# %%
import pandas as pd
import scipy.stats as stats

# Load the healthcare dataset
data = pd.read_csv(r"C:\Users\HP\Downloads\archive (10)\healthcare_dataset.csv")

# Check if the relevant columns are available
if 'Admission Type' in data.columns and 'Billing Amount' in data.columns:
    # Filter data for each admission type
    urgent_billing = data[data['Admission Type'] == 'Urgent']['Billing Amount']
    emergency_billing = data[data['Admission Type'] == 'Emergency']['Billing Amount']
    elective_billing = data[data['Admission Type'] == 'Elective']['Billing Amount']

    # Perform ANOVA test
    f_stat, p_value = stats.f_oneway(urgent_billing, emergency_billing, elective_billing)

    # Display results
    print("ANOVA Test Results:")
    print(f"F-statistic: {f_stat}")
    print(f"P-value: {p_value}")

    # Interpretation
    if p_value < 0.05:
        print("Result: Significant difference in mean billing amounts across admission types (p < 0.05).")
    else:
        print("Result: No significant difference in mean billing amounts across admission types (p >= 0.05).")
else:
    print("Required columns 'Admission_Type' and 'Billing_Amount' are not found in the dataset.")
# Out:
# ANOVA Test Results:
# F-statistic: 0.28440843646706704
# P-value: 0.7524603468639571
# Result: No significant difference in mean billing amounts across admission types (p >= 0.05).
